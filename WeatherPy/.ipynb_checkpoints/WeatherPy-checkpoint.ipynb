# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/User/opt/anaconda3/lib/python3.9/site-packages (0.0.6)
# Requirement already satisfied: kdtree>=0.12 in /Users/User/opt/anaconda3/lib/python3.9/site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 616

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | baise city
# Processing Record 2 of Set 1 | meizhou
# Processing Record 3 of Set 1 | laojunmiao
# Processing Record 4 of Set 1 | greymouth
# Processing Record 5 of Set 1 | port-aux-francais
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | taoudenni
# Processing Record 8 of Set 1 | la ronge
# Processing Record 9 of Set 1 | aasiaat
# Processing Record 10 of Set 1 | uturoa
# Processing Record 11 of Set 1 | wailua homesteads
# Processing Record 12 of Set 1 | blackmans bay
# Processing Record 13 of Set 1 | howrah
# Processing Record 14 of Set 1 | longyearbyen
# Processing Record 15 of Set 1 | nuku'alofa
# Processing Record 16 of Set 1 | nagqu
# Processing Record 17 of Set 1 | corinto
# Processing Record 18 of Set 1 | grytviken
# Processing Record 19 of Set 1 | bilibino
# Processing Record 20 of Set 1 | dudinka
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | port mathurin
# Processing Record 23 of Set 1 | raahe
# Processing Record 24 of Set 1 | rehoboth
# Processing Record 25 of Set 1 | hawaiian paradise park
# Processing Record 26 of Set 1 | flying fish cove
# Processing Record 27 of Set 1 | adamstown
# Processing Record 28 of Set 1 | muang phonsavan
# Processing Record 29 of Set 1 | tiksi
# Processing Record 30 of Set 1 | waitangi
# Processing Record 31 of Set 1 | tataouine
# Processing Record 32 of Set 1 | menongue
# Processing Record 33 of Set 1 | college
# Processing Record 34 of Set 1 | ola
# Processing Record 35 of Set 1 | tolanaro
# Processing Record 36 of Set 1 | ribeira grande
# Processing Record 37 of Set 1 | bredasdorp
# Processing Record 38 of Set 1 | lihue
# Processing Record 39 of Set 1 | olonkinbyen
# Processing Record 40 of Set 1 | tuy hoa
# Processing Record 41 of Set 1 | itoman
# Processing Record 42 of Set 1 | constantia
# Processing Record 43 of Set 1 | turkmenbasy
# Processing Record 44 of Set 1 | taro
# Processing Record 45 of Set 1 | marka
# Processing Record 46 of Set 1 | nar'yan-mar
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | papatowai
# Processing Record 49 of Set 1 | grand falls-windsor
# Processing Record 50 of Set 1 | sisimiut
# Processing Record 0 of Set 2 | gadzhiyevo
# Processing Record 1 of Set 2 | samdari
# Processing Record 2 of Set 2 | iquique
# Processing Record 3 of Set 2 | chonchi
# Processing Record 4 of Set 2 | yellowknife
# Processing Record 5 of Set 2 | remire-montjoly
# Processing Record 6 of Set 2 | wynyard
# Processing Record 7 of Set 2 | talnakh
# Processing Record 8 of Set 2 | smach mean chey
# City not found. Skipping...
# Processing Record 9 of Set 2 | ilulissat
# Processing Record 10 of Set 2 | arraial do cabo
# Processing Record 11 of Set 2 | saipan
# Processing Record 12 of Set 2 | gueoul
# City not found. Skipping...
# Processing Record 13 of Set 2 | praia da vitoria
# Processing Record 14 of Set 2 | celestun
# Processing Record 15 of Set 2 | nova sintra
# Processing Record 16 of Set 2 | atafu village
# Processing Record 17 of Set 2 | isafjordur
# Processing Record 18 of Set 2 | chacabuco
# Processing Record 19 of Set 2 | invercargill
# Processing Record 20 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 21 of Set 2 | banda aceh
# Processing Record 22 of Set 2 | mil'kovo
# Processing Record 23 of Set 2 | nova xavantina
# Processing Record 24 of Set 2 | pratt
# Processing Record 25 of Set 2 | usinsk
# Processing Record 26 of Set 2 | tadine
# Processing Record 27 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 28 of Set 2 | edinburgh of the seven seas
# Processing Record 29 of Set 2 | whitehorse
# Processing Record 30 of Set 2 | smithers
# Processing Record 31 of Set 2 | edd
# Processing Record 32 of Set 2 | west island
# Processing Record 33 of Set 2 | i-n-salah
# Processing Record 34 of Set 2 | alofi
# Processing Record 35 of Set 2 | xiahu
# Processing Record 36 of Set 2 | monrovia
# Processing Record 37 of Set 2 | vadso
# Processing Record 38 of Set 2 | ende
# Processing Record 39 of Set 2 | nemuro
# Processing Record 40 of Set 2 | kargil
# Processing Record 41 of Set 2 | bunda
# Processing Record 42 of Set 2 | bosa
# Processing Record 43 of Set 2 | udachny
# Processing Record 44 of Set 2 | bandon
# Processing Record 45 of Set 2 | bethel
# Processing Record 46 of Set 2 | avarua
# Processing Record 47 of Set 2 | jamestown
# Processing Record 48 of Set 2 | bonthe
# Processing Record 49 of Set 2 | kodinsk
# Processing Record 0 of Set 3 | bhadravati
# Processing Record 1 of Set 3 | dryden
# Processing Record 2 of Set 3 | bridgewater
# Processing Record 3 of Set 3 | nieuw amsterdam
# Processing Record 4 of Set 3 | el calafate
# Processing Record 5 of Set 3 | hamilton
# Processing Record 6 of Set 3 | susuman
# Processing Record 7 of Set 3 | mankachar
# Processing Record 8 of Set 3 | utrik
# Processing Record 9 of Set 3 | glace bay
# Processing Record 10 of Set 3 | luganville
# Processing Record 11 of Set 3 | georgetown
# Processing Record 12 of Set 3 | guanica
# Processing Record 13 of Set 3 | margaret river
# Processing Record 14 of Set 3 | anadyr
# Processing Record 15 of Set 3 | pangoa
# Processing Record 16 of Set 3 | sanctuary point
# Processing Record 17 of Set 3 | abepura
# Processing Record 18 of Set 3 | port lincoln
# Processing Record 19 of Set 3 | sandnessjoen
# Processing Record 20 of Set 3 | goundi
# Processing Record 21 of Set 3 | stanley
# Processing Record 22 of Set 3 | saint-joseph
# Processing Record 23 of Set 3 | mumbwa
# Processing Record 24 of Set 3 | arkhangel'sk
# Processing Record 25 of Set 3 | kuchinda
# Processing Record 26 of Set 3 | lianzhou
# Processing Record 27 of Set 3 | upper grand lagoon
# Processing Record 28 of Set 3 | morehead city
# Processing Record 29 of Set 3 | espargos
# City not found. Skipping...
# Processing Record 30 of Set 3 | san patricio
# Processing Record 31 of Set 3 | aberdeen
# Processing Record 32 of Set 3 | elko
# Processing Record 33 of Set 3 | igrim
# Processing Record 34 of Set 3 | campo gallo
# Processing Record 35 of Set 3 | sur
# Processing Record 36 of Set 3 | ulladulla
# Processing Record 37 of Set 3 | kavaratti
# Processing Record 38 of Set 3 | puerto natales
# Processing Record 39 of Set 3 | constitucion
# Processing Record 40 of Set 3 | kuala belait
# Processing Record 41 of Set 3 | waingapu
# Processing Record 42 of Set 3 | holualoa
# Processing Record 43 of Set 3 | san fernando
# Processing Record 44 of Set 3 | kodiak
# Processing Record 45 of Set 3 | hayma'
# City not found. Skipping...
# Processing Record 46 of Set 3 | bushland beach
# City not found. Skipping...
# Processing Record 47 of Set 3 | klyuchi
# Processing Record 48 of Set 3 | nevada
# Processing Record 49 of Set 3 | tidjikja
# Processing Record 0 of Set 4 | olinda
# Processing Record 1 of Set 4 | cable beach
# City not found. Skipping...
# Processing Record 2 of Set 4 | port saint john's
# Processing Record 3 of Set 4 | cukai
# Processing Record 4 of Set 4 | rongelap
# Processing Record 5 of Set 4 | valparaiso
# Processing Record 6 of Set 4 | sittwe
# Processing Record 7 of Set 4 | bowen
# Processing Record 8 of Set 4 | krasnyy chikoy
# Processing Record 9 of Set 4 | keflavik
# Processing Record 10 of Set 4 | port alfred
# Processing Record 11 of Set 4 | aral
# Processing Record 12 of Set 4 | betio village
# Processing Record 13 of Set 4 | touros
# Processing Record 14 of Set 4 | trapani
# Processing Record 15 of Set 4 | myrina
# Processing Record 16 of Set 4 | ahau
# City not found. Skipping...
# Processing Record 17 of Set 4 | mount pearl
# Processing Record 18 of Set 4 | tazovsky
# Processing Record 19 of Set 4 | lazaro cardenas
# Processing Record 20 of Set 4 | gueltat zemmour
# City not found. Skipping...
# Processing Record 21 of Set 4 | turbat
# Processing Record 22 of Set 4 | punta arenas
# Processing Record 23 of Set 4 | miguel ahumada
# Processing Record 24 of Set 4 | jalqani
# Processing Record 25 of Set 4 | luderitz
# Processing Record 26 of Set 4 | pisco
# Processing Record 27 of Set 4 | kulachi
# Processing Record 28 of Set 4 | pirot
# Processing Record 29 of Set 4 | gamba
# Processing Record 30 of Set 4 | novospasskoye
# Processing Record 31 of Set 4 | walvis bay
# Processing Record 32 of Set 4 | afaahiti
# Processing Record 33 of Set 4 | margate
# Processing Record 34 of Set 4 | kitimat
# Processing Record 35 of Set 4 | troitskoye
# Processing Record 36 of Set 4 | qamdo
# Processing Record 37 of Set 4 | masaka
# Processing Record 38 of Set 4 | chernomorskoye
# Processing Record 39 of Set 4 | funafuti
# Processing Record 40 of Set 4 | libreville
# Processing Record 41 of Set 4 | tsiombe
# Processing Record 42 of Set 4 | natal
# Processing Record 43 of Set 4 | balikpapan
# Processing Record 44 of Set 4 | puerto deseado
# Processing Record 45 of Set 4 | egilsstadir
# Processing Record 46 of Set 4 | la sarre
# Processing Record 47 of Set 4 | papao
# Processing Record 48 of Set 4 | edna
# Processing Record 49 of Set 4 | polyarnyy
# Processing Record 0 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 1 of Set 5 | east london
# Processing Record 2 of Set 5 | sabt alalayah
# City not found. Skipping...
# Processing Record 3 of Set 5 | sitka
# Processing Record 4 of Set 5 | badger
# Processing Record 5 of Set 5 | kingston
# Processing Record 6 of Set 5 | guatrache
# Processing Record 7 of Set 5 | vingt cinq
# City not found. Skipping...
# Processing Record 8 of Set 5 | mezhdurechensk
# Processing Record 9 of Set 5 | sulak
# Processing Record 10 of Set 5 | tura
# Processing Record 11 of Set 5 | hasaki
# Processing Record 12 of Set 5 | isla del bosque
# Processing Record 13 of Set 5 | tralee
# Processing Record 14 of Set 5 | fale old settlement
# Processing Record 15 of Set 5 | acapulco de juarez
# Processing Record 16 of Set 5 | lebu
# Processing Record 17 of Set 5 | heilbron
# Processing Record 18 of Set 5 | tromso
# Processing Record 19 of Set 5 | belokurikha
# Processing Record 20 of Set 5 | villa juarez
# Processing Record 21 of Set 5 | mar del plata
# Processing Record 22 of Set 5 | xiantao
# Processing Record 23 of Set 5 | we
# City not found. Skipping...
# Processing Record 24 of Set 5 | chulakkurgan
# Processing Record 25 of Set 5 | yeniseysk
# Processing Record 26 of Set 5 | cockburn town
# Processing Record 27 of Set 5 | codrington
# Processing Record 28 of Set 5 | mudanjiang
# Processing Record 29 of Set 5 | shimoda
# Processing Record 30 of Set 5 | enewetak
# Processing Record 31 of Set 5 | anori
# Processing Record 32 of Set 5 | mogocha
# Processing Record 33 of Set 5 | vila franca do campo
# Processing Record 34 of Set 5 | ornskoldsvik
# Processing Record 35 of Set 5 | vilyuchinsk
# Processing Record 36 of Set 5 | inarajan village
# Processing Record 37 of Set 5 | thompson
# Processing Record 38 of Set 5 | petawawa
# Processing Record 39 of Set 5 | xilin hot
# Processing Record 40 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 5 | broome
# Processing Record 42 of Set 5 | sinabang
# Processing Record 43 of Set 5 | yagry
# City not found. Skipping...
# Processing Record 44 of Set 5 | kruisfontein
# Processing Record 45 of Set 5 | bamboo flat
# Processing Record 46 of Set 5 | sejenane
# Processing Record 47 of Set 5 | sao paulo de olivenca
# Processing Record 48 of Set 5 | al qadarif
# Processing Record 49 of Set 5 | takab
# Processing Record 0 of Set 6 | el nido
# Processing Record 1 of Set 6 | carnarvon
# Processing Record 2 of Set 6 | sirte
# Processing Record 3 of Set 6 | manokwari
# Processing Record 4 of Set 6 | kyaikkami
# Processing Record 5 of Set 6 | xiongzhou
# Processing Record 6 of Set 6 | daru
# Processing Record 7 of Set 6 | richards bay
# Processing Record 8 of Set 6 | pariaman
# Processing Record 9 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record 10 of Set 6 | tonala
# Processing Record 11 of Set 6 | hadibu
# Processing Record 12 of Set 6 | hermanus
# Processing Record 13 of Set 6 | huanan
# Processing Record 14 of Set 6 | siwa oasis
# Processing Record 15 of Set 6 | moorebank
# Processing Record 16 of Set 6 | iqaluit
# Processing Record 17 of Set 6 | gembu
# Processing Record 18 of Set 6 | strezhevoy
# Processing Record 19 of Set 6 | n'zeto
# Processing Record 20 of Set 6 | demopolis
# Processing Record 21 of Set 6 | kerikeri
# Processing Record 22 of Set 6 | carepa
# Processing Record 23 of Set 6 | prince george
# Processing Record 24 of Set 6 | back mountain
# Processing Record 25 of Set 6 | guiyang
# Processing Record 26 of Set 6 | kataragama
# City not found. Skipping...
# Processing Record 27 of Set 6 | sosnogorsk
# Processing Record 28 of Set 6 | naugachhia
# Processing Record 29 of Set 6 | qaqortoq
# Processing Record 30 of Set 6 | moram
# Processing Record 31 of Set 6 | atar
# Processing Record 32 of Set 6 | frontera
# Processing Record 33 of Set 6 | chamba
# Processing Record 34 of Set 6 | selfoss
# Processing Record 35 of Set 6 | tofol
# Processing Record 36 of Set 6 | sterling
# Processing Record 37 of Set 6 | ebon
# Processing Record 38 of Set 6 | massawa
# Processing Record 39 of Set 6 | santiago de cao
# Processing Record 40 of Set 6 | sengkang
# Processing Record 41 of Set 6 | vila velha
# Processing Record 42 of Set 6 | armidale
# Processing Record 43 of Set 6 | schnaittach
# Processing Record 44 of Set 6 | cargados carajos
# City not found. Skipping...
# Processing Record 45 of Set 6 | ugoofaaru
# Processing Record 46 of Set 6 | kedrovka
# Processing Record 47 of Set 6 | port elizabeth
# Processing Record 48 of Set 6 | rojhan
# Processing Record 49 of Set 6 | archidona
# Processing Record 0 of Set 7 | minas de marcona
# Processing Record 1 of Set 7 | thisted
# Processing Record 2 of Set 7 | mili
# Processing Record 3 of Set 7 | tshabong
# Processing Record 4 of Set 7 | lerwick
# Processing Record 5 of Set 7 | decize
# Processing Record 6 of Set 7 | harper
# Processing Record 7 of Set 7 | wenji
# Processing Record 8 of Set 7 | kudat
# Processing Record 9 of Set 7 | new plymouth
# Processing Record 10 of Set 7 | castillos
# Processing Record 11 of Set 7 | hailar
# Processing Record 12 of Set 7 | labrador city
# Processing Record 13 of Set 7 | tosontsengel
# Processing Record 14 of Set 7 | aginskoye
# Processing Record 15 of Set 7 | kidal
# Processing Record 16 of Set 7 | prince rupert
# Processing Record 17 of Set 7 | bikenibeu village
# Processing Record 18 of Set 7 | santa pola
# Processing Record 19 of Set 7 | kristiansund
# Processing Record 20 of Set 7 | sabang
# Processing Record 21 of Set 7 | saldanha
# Processing Record 22 of Set 7 | daday
# Processing Record 23 of Set 7 | fort bragg
# Processing Record 24 of Set 7 | ouagadougou
# Processing Record 25 of Set 7 | ixtapa
# Processing Record 26 of Set 7 | aioun
# Processing Record 27 of Set 7 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 28 of Set 7 | auki
# Processing Record 29 of Set 7 | babayevo
# Processing Record 30 of Set 7 | port douglas
# Processing Record 31 of Set 7 | carutapera
# Processing Record 32 of Set 7 | ust-nera
# Processing Record 33 of Set 7 | perugorria
# Processing Record 34 of Set 7 | olgii
# City not found. Skipping...
# Processing Record 35 of Set 7 | zahedan
# Processing Record 36 of Set 7 | roosevelt
# Processing Record 37 of Set 7 | dolores
# Processing Record 38 of Set 7 | port-vila
# Processing Record 39 of Set 7 | aweil
# Processing Record 40 of Set 7 | cu chi
# Processing Record 41 of Set 7 | labytnangi
# Processing Record 42 of Set 7 | kuala kangsar
# Processing Record 43 of Set 7 | homer
# Processing Record 44 of Set 7 | kangding
# Processing Record 45 of Set 7 | turpan
# Processing Record 46 of Set 7 | sakakah
# Processing Record 47 of Set 7 | chibougamau
# Processing Record 48 of Set 7 | nongstoin
# Processing Record 49 of Set 7 | yamada
# Processing Record 0 of Set 8 | happy valley-goose bay
# Processing Record 1 of Set 8 | mujiayingzi
# Processing Record 2 of Set 8 | arua
# Processing Record 3 of Set 8 | khandyga
# Processing Record 4 of Set 8 | mossel bay
# Processing Record 5 of Set 8 | quinte west
# Processing Record 6 of Set 8 | kroya
# Processing Record 7 of Set 8 | vernon
# Processing Record 8 of Set 8 | zemio
# Processing Record 9 of Set 8 | egersund
# Processing Record 10 of Set 8 | cadale
# Processing Record 11 of Set 8 | al kharijah
# Processing Record 12 of Set 8 | seminole
# Processing Record 13 of Set 8 | deming
# Processing Record 14 of Set 8 | kostanay
# Processing Record 15 of Set 8 | zhangye
# Processing Record 16 of Set 8 | neftcala
# Processing Record 17 of Set 8 | at taj
# Processing Record 18 of Set 8 | cabo san lucas
# Processing Record 19 of Set 8 | beawar
# Processing Record 20 of Set 8 | kupang
# Processing Record 21 of Set 8 | sanibel
# Processing Record 22 of Set 8 | chadron
# Processing Record 23 of Set 8 | hirara
# Processing Record 24 of Set 8 | newman
# Processing Record 25 of Set 8 | illizi
# Processing Record 26 of Set 8 | fort mcmurray
# Processing Record 27 of Set 8 | muzayri'
# City not found. Skipping...
# Processing Record 28 of Set 8 | sinop
# Processing Record 29 of Set 8 | eureka
# Processing Record 30 of Set 8 | puerto armuelles
# Processing Record 31 of Set 8 | zhelezinka
# Processing Record 32 of Set 8 | cill airne
# Processing Record 33 of Set 8 | bel ombre
# Processing Record 34 of Set 8 | bandarbeyla
# Processing Record 35 of Set 8 | opuwo
# Processing Record 36 of Set 8 | piacabucu
# Processing Record 37 of Set 8 | savave village
# City not found. Skipping...
# Processing Record 38 of Set 8 | prainha
# Processing Record 39 of Set 8 | tazacorte
# Processing Record 40 of Set 8 | weno
# Processing Record 41 of Set 8 | chinhoyi
# Processing Record 42 of Set 8 | coquimbo
# Processing Record 43 of Set 8 | sikar
# Processing Record 44 of Set 8 | matoury
# Processing Record 45 of Set 8 | emerald
# Processing Record 46 of Set 8 | seka
# Processing Record 47 of Set 8 | tobol'sk
# Processing Record 48 of Set 8 | faya-largeau
# Processing Record 49 of Set 8 | north battleford
# Processing Record 0 of Set 9 | chegdomyn
# Processing Record 1 of Set 9 | ambon
# Processing Record 2 of Set 9 | huancavelica
# Processing Record 3 of Set 9 | queenstown
# Processing Record 4 of Set 9 | kawm umbu
# Processing Record 5 of Set 9 | brisas de zicatela
# Processing Record 6 of Set 9 | tobi village
# City not found. Skipping...
# Processing Record 7 of Set 9 | yashkul'
# Processing Record 8 of Set 9 | asaita
# Processing Record 9 of Set 9 | brookings
# Processing Record 10 of Set 9 | mount isa
# Processing Record 11 of Set 9 | machico
# Processing Record 12 of Set 9 | sola
# Processing Record 13 of Set 9 | howard springs
# Processing Record 14 of Set 9 | coyhaique
# Processing Record 15 of Set 9 | mogok
# Processing Record 16 of Set 9 | wuwei
# Processing Record 17 of Set 9 | arteche
# Processing Record 18 of Set 9 | laguna
# Processing Record 19 of Set 9 | punto fijo
# Processing Record 20 of Set 9 | tsengel
# Processing Record 21 of Set 9 | geraldton
# Processing Record 22 of Set 9 | qarazhal
# Processing Record 23 of Set 9 | la puebla de montalban
# Processing Record 24 of Set 9 | urangan
# Processing Record 25 of Set 9 | seaside
# Processing Record 26 of Set 9 | mahdia
# Processing Record 27 of Set 9 | south hedland
# Processing Record 28 of Set 9 | colonia
# Processing Record 29 of Set 9 | fortuna
# Processing Record 30 of Set 9 | ibarreta
# Processing Record 31 of Set 9 | waiuku
# Processing Record 32 of Set 9 | serres
# Processing Record 33 of Set 9 | katabu
# Processing Record 34 of Set 9 | las varillas
# Processing Record 35 of Set 9 | bairnsdale
# Processing Record 36 of Set 9 | midvagur
# Processing Record 37 of Set 9 | nikolayevsk-on-amure
# Processing Record 38 of Set 9 | basawul
# Processing Record 39 of Set 9 | saurimo
# Processing Record 40 of Set 9 | noosa heads
# Processing Record 41 of Set 9 | long beach
# Processing Record 42 of Set 9 | teuva
# Processing Record 43 of Set 9 | aljustrel
# Processing Record 44 of Set 9 | namtsy
# Processing Record 45 of Set 9 | saint-francois
# Processing Record 46 of Set 9 | leamington
# Processing Record 47 of Set 9 | puerto esperanza
# Processing Record 48 of Set 9 | rodolfo sanchez taboada
# Processing Record 49 of Set 9 | vredenburg
# City not found. Skipping...
# Processing Record 0 of Set 10 | callao
# Processing Record 1 of Set 10 | acarau
# Processing Record 2 of Set 10 | monze
# Processing Record 3 of Set 10 | chinde
# Processing Record 4 of Set 10 | paraiso
# Processing Record 5 of Set 10 | mount gambier
# Processing Record 6 of Set 10 | taltal
# Processing Record 7 of Set 10 | sishilichengzi
# City not found. Skipping...
# Processing Record 8 of Set 10 | mwaro
# Processing Record 9 of Set 10 | hithadhoo
# Processing Record 10 of Set 10 | xifeng
# Processing Record 11 of Set 10 | vorgashor
# Processing Record 12 of Set 10 | tell city
# Processing Record 13 of Set 10 | guerrero negro
# Processing Record 14 of Set 10 | okhotsk
# Processing Record 15 of Set 10 | aripuana
# Processing Record 16 of Set 10 | mariental
# Processing Record 17 of Set 10 | saint-pierre
# Processing Record 18 of Set 10 | akureyri
# Processing Record 19 of Set 10 | enriquillo
# Processing Record 20 of Set 10 | salamanca
# Processing Record 21 of Set 10 | island harbour
# Processing Record 22 of Set 10 | tyazhinskiy
# Processing Record 23 of Set 10 | margarita belen
# Processing Record 24 of Set 10 | vershino-darasunskiy
# Processing Record 25 of Set 10 | mogadishu
# Processing Record 26 of Set 10 | shiyan
# Processing Record 27 of Set 10 | yuanlin
# Processing Record 28 of Set 10 | goure
# Processing Record 29 of Set 10 | knyaze-volkonskoye
# Processing Record 30 of Set 10 | mahina
# Processing Record 31 of Set 10 | la passe
# Processing Record 32 of Set 10 | kilju
# Processing Record 33 of Set 10 | chake chake
# Processing Record 34 of Set 10 | sarmiento
# Processing Record 35 of Set 10 | noumea
# Processing Record 36 of Set 10 | shindand
# Processing Record 37 of Set 10 | puerto aysen
# Processing Record 38 of Set 10 | modra
# Processing Record 39 of Set 10 | bubaque
# Processing Record 40 of Set 10 | kinzan
# Processing Record 41 of Set 10 | merizo village
# Processing Record 42 of Set 10 | la'ie
# Processing Record 43 of Set 10 | majene
# Processing Record 44 of Set 10 | vodice
# Processing Record 45 of Set 10 | lusaka
# Processing Record 46 of Set 10 | lago da pedra
# Processing Record 47 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 48 of Set 10 | burley
# Processing Record 49 of Set 10 | doka
# Processing Record 0 of Set 11 | lensk
# Processing Record 1 of Set 11 | zaozersk
# Processing Record 2 of Set 11 | mazagao
# Processing Record 3 of Set 11 | karratha
# Processing Record 4 of Set 11 | pangody
# Processing Record 5 of Set 11 | glendale
# Processing Record 6 of Set 11 | san rafael del yuma
# Processing Record 7 of Set 11 | nabire
# Processing Record 8 of Set 11 | kashmor
# Processing Record 9 of Set 11 | awjilah
# Processing Record 10 of Set 11 | la union
# Processing Record 11 of Set 11 | sassnitz
# Processing Record 12 of Set 11 | semporna
# Processing Record 13 of Set 11 | el daein
# City not found. Skipping...
# Processing Record 14 of Set 11 | korla
# Processing Record 15 of Set 11 | qapqal
# City not found. Skipping...
# Processing Record 16 of Set 11 | edgewater
# Processing Record 17 of Set 11 | piranshahr
# Processing Record 18 of Set 11 | gdansk
# Processing Record 19 of Set 11 | oriximina
# Processing Record 20 of Set 11 | deschutes river woods
# Processing Record 21 of Set 11 | belyy yar
# Processing Record 22 of Set 11 | thunder bay
# Processing Record 23 of Set 11 | abraham's bay
# City not found. Skipping...
# Processing Record 24 of Set 11 | anloga
# Processing Record 25 of Set 11 | amarillo
# Processing Record 26 of Set 11 | mata-utu
# Processing Record 27 of Set 11 | yakutsk
# Processing Record 28 of Set 11 | houghton
# Processing Record 29 of Set 11 | whakatane
# Processing Record 30 of Set 11 | antsiranana
# Processing Record 31 of Set 11 | palmer
# Processing Record 32 of Set 11 | fig tree
# Processing Record 33 of Set 11 | orkney
# Processing Record 34 of Set 11 | hammerfest
# Processing Record 35 of Set 11 | itaituba
# Processing Record 36 of Set 11 | emmett
# Processing Record 37 of Set 11 | pasuquin
# Processing Record 38 of Set 11 | jaciara
# Processing Record 39 of Set 11 | veymandoo
# City not found. Skipping...
# Processing Record 40 of Set 11 | sierra grande
# Processing Record 41 of Set 11 | puerto real
# Processing Record 42 of Set 11 | fauske
# Processing Record 43 of Set 11 | bumba
# Processing Record 44 of Set 11 | bouarfa
# Processing Record 45 of Set 11 | malpe
# Processing Record 46 of Set 11 | mecca
# Processing Record 47 of Set 11 | penzance
# Processing Record 48 of Set 11 | melfort
# Processing Record 49 of Set 11 | mejit
# Processing Record 0 of Set 12 | sume
# Processing Record 1 of Set 12 | kapuskasing
# Processing Record 2 of Set 12 | hilo
# Processing Record 3 of Set 12 | giado
# Processing Record 4 of Set 12 | lorengau
# Processing Record 5 of Set 12 | raton
# Processing Record 6 of Set 12 | basco
# Processing Record 7 of Set 12 | kudahuvadhoo
# Processing Record 8 of Set 12 | bure
# Processing Record 9 of Set 12 | faxinal
# Processing Record 10 of Set 12 | ancud
# Processing Record 11 of Set 12 | mpulungu
# Processing Record 12 of Set 12 | kailua-kona
# Processing Record 13 of Set 12 | selebi-phikwe
# Processing Record 14 of Set 12 | tauranga
# Processing Record 15 of Set 12 | batangafo
# Processing Record 16 of Set 12 | maturin
# Processing Record 17 of Set 12 | new norfolk
# Processing Record 18 of Set 12 | hami
# Processing Record 19 of Set 12 | assab
# Processing Record 20 of Set 12 | savannakhet
# Processing Record 21 of Set 12 | sao mateus do maranhao
# Processing Record 22 of Set 12 | tual
# Processing Record 23 of Set 12 | sakchu-up
# Processing Record 24 of Set 12 | nizhneangarsk
# Processing Record 25 of Set 12 | bardaskan
# City not found. Skipping...
# Processing Record 26 of Set 12 | tevriz
# Processing Record 27 of Set 12 | buritis
# Processing Record 28 of Set 12 | kalmunai
# Processing Record 29 of Set 12 | coronel suarez
# Processing Record 30 of Set 12 | ribas do rio pardo
# Processing Record 31 of Set 12 | tenancingo de degollado
# Processing Record 32 of Set 12 | saint croix
# Processing Record 33 of Set 12 | kisangani
# Processing Record 34 of Set 12 | san antonio de pale
# Processing Record 35 of Set 12 | argo
# Processing Record 36 of Set 12 | isle of lewis
# City not found. Skipping...
# Processing Record 37 of Set 12 | inebolu
# Processing Record 38 of Set 12 | tocopilla
# Processing Record 39 of Set 12 | salalah
# Processing Record 40 of Set 12 | cidreira
# Processing Record 41 of Set 12 | la fria
# Processing Record 42 of Set 12 | harlingen
# Processing Record 43 of Set 12 | tabou
# Processing Record 44 of Set 12 | hovd
# Processing Record 45 of Set 12 | lhasa
# Processing Record 46 of Set 12 | sovetskaya gavan'
# Processing Record 47 of Set 12 | jackson
# Processing Record 48 of Set 12 | karaton
# Processing Record 49 of Set 12 | nyagan
# Processing Record 0 of Set 13 | motygino
# Processing Record 1 of Set 13 | along
# Processing Record 2 of Set 13 | minot air force base
# Processing Record 3 of Set 13 | broken hill
# Processing Record 4 of Set 13 | gondar
# Processing Record 5 of Set 13 | mirny
# Processing Record 6 of Set 13 | isangel
# Processing Record 7 of Set 13 | alice springs
# Processing Record 8 of Set 13 | south venice
# Processing Record 9 of Set 13 | ghat
# Processing Record 10 of Set 13 | gorontalo
# Processing Record 11 of Set 13 | filadelfia
# Processing Record 12 of Set 13 | nanning
# Processing Record 13 of Set 13 | mazatlan
# Processing Record 14 of Set 13 | kapa'a
# Processing Record 15 of Set 13 | barcelos
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          584
# Lat           584
# Lng           584
# Max Temp      584
# Humidity      584
# Cloudiness    584
# Wind Speed    584
# Country       584
# Date          584
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         baise city  23.8997  106.6133     25.13        96          90
# 1            meizhou  24.2977  116.1072     26.29        93          98
# 2         laojunmiao  39.8333   97.7333     22.47        23           0
# 3          greymouth -42.4667  171.2000      5.85        83          97
# 4  port-aux-francais -49.3500   70.2167      1.68        64          52
#
#    Wind Speed Country        Date
# 0        0.62      CN  1689868302
# 1        1.02      CN  1689868302
# 2        3.74      CN  1689868302
# 3        6.30      NZ  1689868061
# 4       18.96      TF  1689868302

# %%
# Export the City_Data into a csv

city_data_df.to_csv("cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               baise city  23.8997  106.6133     25.13        96          90
# 1                  meizhou  24.2977  116.1072     26.29        93          98
# 2               laojunmiao  39.8333   97.7333     22.47        23           0
# 3                greymouth -42.4667  171.2000      5.85        83          97
# 4        port-aux-francais -49.3500   70.2167      1.68        64          52
#
#          Wind Speed Country        Date
# City_ID
# 0              0.62      CN  1689868302
# 1              1.02      CN  1689868302
# 2              3.74      CN  1689868302
# 3              6.30      NZ  1689868061
# 4             18.96      TF  1689868302

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor="black")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (c))")
plt.title("City Max Latitude vs. Temperature(%s)"% time.strftime("%Y-%m-%d"))
plt.grid(True)

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor="black")
plt.xlabel("Latitude")
plt.ylabel("Max Humidity (%))")
plt.title("City Max Latitude vs. Humidity(%s)"% time.strftime("%Y-%m-%d"))
plt.grid(True)

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor="black")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("City Max Latitude vs. Humidity(%s)"% time.strftime("%Y-%m-%d"))
plt.grid(True)

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor="black")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Max Latitude vs. Wind Speed(%s)"% time.strftime("%Y-%m-%d"))
plt.grid(True)

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):

    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x_values,y_values, edgecolor="black")
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    plt.grid(True)
    print(f"the rvalue is ",(rvalue))
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        baise city  23.8997  106.6133     25.13        96          90
# 1           meizhou  24.2977  116.1072     26.29        93          98
# 2        laojunmiao  39.8333   97.7333     22.47        23           0
# 6         taoudenni  22.6783   -3.9836     47.35         5           0
# 7          la ronge  55.1001 -105.2842     19.12        77          75
#
#          Wind Speed Country        Date
# City_ID
# 0              0.62      CN  1689868302
# 1              1.02      CN  1689868302
# 2              3.74      CN  1689868302
# 6              4.93      ML  1689868072
# 7              2.57      CA  1689868302

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] <0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3                greymouth -42.4667  171.2000      5.85        83          97
# 4        port-aux-francais -49.3500   70.2167      1.68        64          52
# 5             puerto ayora  -0.7393  -90.3518     27.98        92          72
# 9                   uturoa -16.7333 -151.4333     24.44        64          28
# 11           blackmans bay -43.0167  147.3167      6.40        85          75
#
#          Wind Speed Country        Date
# City_ID
# 3              6.30      NZ  1689868061
# 4             18.96      TF  1689868302
# 5              1.79      EC  1689868043
# 9              8.19      PF  1689868303
# 11             2.57      AU  1689868303

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_value=northern_hemi_df["Lat"]
y_value=northern_hemi_df["Max Temp"]
plot_linear_regression(x_value, y_value, "Temperature", (6,-10))
# Out:
# the rvalue is  -0.5968340383531437

# %%
# Linear regression on Southern Hemisphere
x_value=southern_hemi_df["Lat"]
y_value=southern_hemi_df["Max Temp"]
plot_linear_regression(x_value, y_value, "Temperature", (-30,5))
# Out:
# the rvalue is  0.8741093860277621

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value=northern_hemi_df["Lat"]
y_value=northern_hemi_df["Humidity"]
plot_linear_regression(x_value, y_value, "Humidity", (60,20))
# Out:
# the rvalue is  0.01626745058373863

# %%
# Southern Hemisphere
x_value=southern_hemi_df["Lat"]
y_value=southern_hemi_df["Humidity"]
plot_linear_regression(x_value, y_value, "Humidity", (-55,20))
# Out:
# the rvalue is  -0.17899374236743526

# %% [markdown]
# **Discussion about the linear relationship:** The r value keeps decreasing

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value=northern_hemi_df["Lat"]
y_value=northern_hemi_df["Cloudiness"]
plot_linear_regression(x_value, y_value, "Cloudiness", (75,70))
# Out:
# the rvalue is  -0.07770131022309373

# %%
# Southern Hemisphere
x_value=southern_hemi_df["Lat"]
y_value=southern_hemi_df["Cloudiness"]
plot_linear_regression(x_value, y_value, "Cloudiness", (-55,30))
# Out:
# the rvalue is  -0.3660980746093861

# %% [markdown]
# **Discussion about the linear relationship:** both r values are negative

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_value=northern_hemi_df["Lat"]
y_value=northern_hemi_df["Wind Speed"]
plot_linear_regression(x_value, y_value, "Wind Speed", (0,15))
# Out:
# the rvalue is  -0.13594986170155782

# %%
# Southern Hemisphere
x_value=southern_hemi_df["Lat"]
y_value=southern_hemi_df["Wind Speed"]
plot_linear_regression(x_value, y_value, "Wind Speed", (-55,15))
# Out:
# the rvalue is  -0.17562195907425723
